# %%
x = (32, 10)
y = (10,)

print(len(x))
# Out:
# 2

# %%
print(range(x[1]))
# Out:
# range(0, 10)

# %%
def naive_add_matrix_and_vector(x,y):
    assert len(x.shape) == 2
    assert len(y.shape) ==1
    assert x.shape[1] == y.shape[0]
    
    x = x.copy()
    for i in range(x.shape[0]):   #range(x[1]) = range(0, 10)
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((32, 10))
y = np.random.random((10))

# %%
naive_add_matrix_and_vector(x,y)
# Out:
# array([[1.24925555, 1.26532867, 0.98915885, 0.94774684, 0.3290168 ,
#         1.35513961, 0.40734325, 1.26148417, 0.76003541, 0.67110303],
#        [1.77032024, 0.62344043, 0.47601382, 1.04997702, 0.42925764,
#         1.40119335, 0.46431116, 1.23415094, 1.40313015, 0.34054143],
#        [1.14199431, 0.65134735, 0.52406055, 0.87812445, 0.28546384,
#         1.37981063, 0.94198763, 0.65146484, 0.88162615, 0.91696915],
#        [0.81916279, 1.56273995, 1.01384146, 1.31327483, 0.27678986,
#         1.73847421, 1.13608197, 1.31115199, 1.08557586, 0.46686393],
#        [0.91209217, 1.21360119, 0.21951479, 1.2492084 , 0.7820973 ,
#         0.96480469, 0.40240312, 1.10459206, 0.81472883, 0.31845692],
#        [1.60992184, 1.29268672, 1.06717242, 1.0565702 , 0.94262272,
#         1.32838584, 0.33349739, 1.1715478 , 1.48386576, 0.31683849],
#        [1.2338341 , 1.06754466, 0.61132384, 1.43919572, 0.4840543 ,
#         1.48479697, 1.02233357, 0.8497611 , 1.14652234, 0.53908589],
#        [1.31232393, 0.70296411, 0.46597708, 0.97408426, 0.6408472 ,
#         1.51767207, 0.81791358, 0.5466797 , 0.60971425, 0.6716568 ],
#        [1.08289419, 0.93814886, 0.76467714, 0.98840549, 0.22599978,
#         1.08976462, 0.22437786, 1.18064689, 1.22149212, 0.22778191],
#        [1.27311695, 0.5940666 , 1.04703037, 1.08737495, 0.89758446,
#         1.51968144, 0.87584935, 1.37400641, 0.80838199, 0.35329506],
#        [0.81935352, 1.50418603, 0.32086794, 0.58161303, 0.55124777,
#         1.45268256, 0.89001123, 1.23297116, 1.25812294, 0.4232355 ],
#        [1.51457237, 0.77236151, 0.73747984, 0.52009296, 0.86492007,
#         1.34739758, 0.56859722, 1.15760721, 1.01650135, 0.6690516 ],
#        [0.80826941, 1.54815072, 0.22497336, 0.52403615, 0.76625982,
#         1.27593724, 0.82245865, 1.34695651, 1.22767356, 0.18258573],
#        [0.85272573, 1.19076878, 1.03148937, 1.34727284, 0.97929766,
#         1.12849637, 0.30782489, 0.91749052, 0.87264239, 0.86432   ],
#        [1.63321097, 0.64585745, 0.46932901, 1.20637542, 0.47471443,
#         1.71810778, 0.27073558, 0.6581624 , 0.64790203, 0.12777874],
#        [1.06601183, 1.35927611, 0.54691491, 0.74503385, 1.16709589,
#         1.21297938, 0.93195023, 1.37550278, 1.0265092 , 0.52480505],
#        [1.28571133, 1.03758655, 0.39542557, 1.23697424, 1.02588346,
#         1.40396779, 0.4231132 , 0.7851599 , 1.46971513, 0.6081621 ],
#        [1.59413324, 1.26857762, 0.27864939, 1.07660487, 0.29534811,
#         1.24312062, 0.29872249, 0.93335994, 0.82920018, 1.01823129],
#        [1.25603725, 1.50528363, 0.54137584, 1.21257635, 0.49563673,
#         1.11110935, 0.23362158, 0.58651007, 1.1932528 , 0.95123061],
#        [0.88688299, 0.67666428, 0.72832495, 1.50819418, 0.33020215,
#         1.09863457, 1.04933783, 0.97523   , 1.28328029, 0.66433062],
#        [1.39497272, 0.73417605, 0.33016839, 1.35592907, 0.22232218,
#         1.18818198, 0.37739769, 0.98400957, 0.55412788, 0.17535763],
#        [0.98751021, 1.54581419, 1.00749069, 0.93786737, 1.01056547,
#         1.03966557, 0.49148052, 1.08511092, 0.70105076, 0.19114219],
#        [1.35965518, 0.60913525, 1.10546622, 1.34963954, 0.55493754,
#         1.5240241 , 0.24474962, 1.21764685, 1.29090744, 0.59728481],
#        [1.06063135, 1.19027817, 0.35391927, 1.0686562 , 0.90977098,
#         0.95673039, 0.86934266, 0.61193963, 0.68426432, 0.29750911],
#        [1.43021995, 0.83149667, 0.23526542, 0.72377822, 0.79116135,
#         1.49107752, 0.51328652, 1.35081647, 1.31342301, 0.23524679],
#        [1.27645021, 1.45450643, 0.2189549 , 0.84156577, 1.13956315,
#         1.66442655, 0.39001008, 1.1567894 , 0.59997759, 0.36418934],
#        [1.32633836, 1.34460343, 0.63275912, 0.99612976, 0.60487673,
#         0.87267195, 0.44151367, 0.93032911, 0.98592874, 0.34982817],
#        [1.29147935, 1.52730287, 0.86802364, 1.29361588, 0.47801661,
#         0.98680726, 0.41554232, 1.22944431, 0.9446825 , 0.7834272 ],
#        [0.97392537, 1.2559351 , 0.27512747, 0.77109791, 0.32388971,
#         1.10956568, 0.77698268, 0.78041862, 0.62765497, 0.27556311],
#        [1.71609893, 1.54624803, 0.56166469, 0.59873277, 0.90552212,
#         0.90556455, 0.93902621, 1.01865302, 1.47891469, 0.39534803],
#        [1.04146857, 1.22277536, 0.45232163, 0.52267299, 0.41239975,
#         0.86119365, 0.19611153, 1.13975704, 1.03329441, 0.30749678],
#        [0.95707821, 0.80105376, 0.62966614, 1.26673511, 0.66972162,
#         0.83403037, 0.75152035, 0.86604931, 0.69684274, 0.72213826]])

# %%
print(y.shape)
# Out:
# (10,)

# %%
z = np.maximum(x,y)

# %%
print(z.shape)
# Out:
# (32, 10)

# %%
print(y.shape[0])
# Out:
# 10

# %%
print(x.shape[1])
# Out:
# 10

# %%
print(len(x.shape))
# Out:
# 2

# %%
x = np.random.random((6,4,5))
print(x)
# Out:
# [[[0.83263147 0.82128738 0.00388658 0.30658671 0.54470565]
#   [0.45739167 0.14139575 0.70498514 0.60620052 0.7155321 ]
#   [0.96112482 0.27533298 0.28540818 0.32055223 0.84135301]
#   [0.66839225 0.61119879 0.96377898 0.43660768 0.12480602]]
#
#  [[0.0596863  0.26947889 0.87267817 0.90689755 0.64223147]
#   [0.03488885 0.57295463 0.5724387  0.02027675 0.3040414 ]
#   [0.51812786 0.10493499 0.48308547 0.6932368  0.87214784]
#   [0.28606134 0.78465116 0.86395171 0.58556832 0.05095862]]
#
#  [[0.89891038 0.38742521 0.10451244 0.98540703 0.52423278]
#   [0.27200033 0.02386687 0.76741519 0.22543588 0.4854954 ]
#   [0.76394721 0.95012899 0.30733388 0.03485276 0.82797048]
#   [0.30152488 0.72249    0.33200073 0.69901429 0.73447358]]
#
#  [[0.73847498 0.24189359 0.55574925 0.10183893 0.77890798]
#   [0.7892799  0.67064881 0.9242538  0.94613042 0.9453883 ]
#   [0.5482655  0.17576003 0.14032616 0.52832133 0.61411532]
#   [0.72321212 0.30729496 0.87994955 0.22204842 0.46525016]]
#
#  [[0.28032549 0.9165059  0.31282623 0.40765671 0.4855749 ]
#   [0.36801467 0.78099029 0.34219606 0.04983733 0.47768379]
#   [0.01895932 0.18772219 0.67168502 0.80707059 0.65582143]
#   [0.44988295 0.39261504 0.61885574 0.00650391 0.84658033]]
#
#  [[0.37600069 0.74965649 0.77339472 0.34609083 0.6925285 ]
#   [0.97665174 0.2291046  0.66634141 0.37496157 0.93626392]
#   [0.35260373 0.40012288 0.82178191 0.94747581 0.22633346]
#   [0.30376266 0.78818085 0.13175615 0.84702759 0.45529031]]]

# %%
print(len(x.shape))
# Out:
# 3
